# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read csv file
# - Pandas kütüphanesi kullanarak csv okuma işlemi
# - Reading csv using pandas library

# %%
df = pd.read_csv("ds_salaries.csv")

# %% [markdown]
# ### VERİ SETİNİ İNCELEMEYE BAŞLIYORUZ
# ### WE ARE STARTING TO REVIEW THE DATASET

# %% [markdown]
# * Veri setinin ilk beş elamanına bakıyoruz head() fonksiyonu ile bize default olarak ilk 5 değeri döndürüyor.
# * We look at the first five elements of the data set, and the head() function returns the first 5 values by default.

# %%
df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %% [markdown]
# * Veri setinin ilk beş elamanına bakıyoruz tail() fonksiyonu ile bize default olarak son 5 değeri döndürüyor.
# * We look at the first five elements of the data set, and the tail() function returns the last 5 values by default.

# %%
df.tail()
# Out:
#       work_year experience_level employment_type                 job_title  \
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# ...

# %% [markdown]
# * info() fonksiyonu ile veri setimiz ile ilgili detaylı bir bilgi elde ediyoruz.
# * Veri setimiz 11 sütunda oluşuyor.
# * Veri setimizdeki toplam örnek sayısı(entries) 2584.
# * Sütunlardaki verilerin hangi veri tipinde olduğunu görüyoruz. 4 tanesi int64 ve 7 tanesi ise object veri tipinde.
#
# --------------------------------------------------------------------------------------------------------------------
#
# * With the info() function, we get detailed information about our data set.
# * Our dataset consists of 11 columns.
# * Total number of samples (entries) in our dataset is 2584.
# * We see which data type the data in the columns are. 4 of them are int64 and 7 of them are of object data type.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2584 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           2584 non-null   int64
#  1   experience_level    2584 non-null   object
#  2   employment_type     2584 non-null   object
#  3   job_title           2584 non-null   object
#  4   salary              2584 non-null   int64
#  5   salary_currency     2584 non-null   object
#  6   salary_in_usd       2584 non-null   int64
#  7   employee_residence  2584 non-null   object
#  8   remote_ratio        2584 non-null   int64
#  9   company_location    2584 non-null   object
#  10  company_size        2584 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 242.2+ KB

# %% [markdown]
# * drop_duplicates() fonksiyonu kullanarak varsa aynı olan satırlar onları siliyoruz.
# * info() fonksiyonu kullanarak tekrar örnek saysına bakyığımızda herhangi bir değişiklik olmadığını görüyoruz.
# * Using the drop_duplicates() function, we delete lines that are the same, if any.
# * When we look at the number of samples again using the info() function, we see that there is no change.

# %%
df = df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2584 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           2584 non-null   int64
#  1   experience_level    2584 non-null   object
#  2   employment_type     2584 non-null   object
#  3   job_title           2584 non-null   object
#  4   salary              2584 non-null   int64
#  5   salary_currency     2584 non-null   object
#  6   salary_in_usd       2584 non-null   int64
#  7   employee_residence  2584 non-null   object
#  8   remote_ratio        2584 non-null   int64
#  9   company_location    2584 non-null   object
#  10  company_size        2584 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 242.2+ KB

# %% [markdown]
# * count() fonksiyonu ile tüm sütunlardaki eleman sayılarına bakıyoruz.
# * Tüm sütunlarda eşit sayıda örnek var. Satırlarda boş değer olmadığını gösterir.(Veri setinde boş değer olup olmadığını başka bir fonksiyon kullanarakta yapabiliriz.)
# * We look at the number of elements in all columns with the count() function.
# * All columns have an equal number of samples. It shows that there are no null values in the rows. (We can also use another function if there is a null value in the data set.)

# %%
df.count()
# Out:
# work_year             2584
# experience_level      2584
# employment_type       2584
# job_title             2584
# salary                2584
# salary_currency       2584
# salary_in_usd         2584
# employee_residence    2584
# remote_ratio          2584
# company_location      2584
# company_size          2584
# dtype: int64

# %% [markdown]
# * Aşağıdaki kullandığımız yöntem ile boş değerlerin toplamını alabiliriz.
# * Boş değer olmadığını aşağıdaki çıktıyla görüyoruz.
# * We can get the sum of the null values with the method we use below.
# * We see that there is no null value with the following output.

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# * describe() fonksiyonu ile veri setimiz hakkında önemli matematiksel değerler alabiliriz.
# * Örneğin eleman sayısı,ortalama,standart sapma,en düşük değer,en büyük değer.
# * describe() fonksiyonu veri setinde sayısal değer olan sütünları alır.
# -------------------------------------------------------------------------------------------------------------------
# * With the describe() function, we can get important mathematical values about our dataset.
# * For example, number of elements, mean, standard deviation, minimum value, maximum value.
# * The describe() function takes columns with numeric values in the dataset.

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  2584.000000  2.584000e+03    2584.000000   2584.000000
# mean   2022.301084  2.103653e+05  133409.280186     50.483746
# std       0.749179  8.080375e+05   67136.837329     48.163707
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  9.000000e+04   84975.000000      0.000000
# 50%    2022.000000  1.346300e+05  130000.000000     50.000000
# 75%    2023.000000  1.825625e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# * Veri setimizi tekrar incelediğimizde 2 sütunun maaş ile ilgili olduğunu göryoruz.
# * salary sütunundaki maaş değerleri ilgili ülkeye göre belirlenmiş maaşlar ve birimi ise salary_currency sütununda gösterilmiş.
# * salary_in_usd ise dolar cinsinden maaşları.
# * Sadece salary_in_usd sutununu kullanarak veri setimizde olan ülkelerdeki işlerin dolar cinsinden maaşlarını kullanabiliriz. salary sütunundaki tüm değerler dolar cinsine çevrilmiş hali salary_in_usd sütununda bulunuyor.
# * salary ve salary_currency sütununa ihtiyacımız olmayacak sadece dolar cinsindeki maaşları kullanacağız.
# * unique() fonksiyonu ile salary_currency sütunundaki para birimi çeşitine baktığımızda 20 adet para birimini ortak bir para birimine çevirmeye gerek kalmadı.
# ---------------------------------------------------------------------------------------------------------------
# * When we re-examine our data set, we see that 2 columns are related to salary.
# * Salary values in the salary column are determined by the relevant country, and the unit is shown in the salary_currency column.
# * salary_in_usd is their salary in dollars.
# * Using only the salary_in_usd column, we can use the dollar-denominated salaries of jobs in the countries in our dataset. All values in the salary column are converted to dollars and are available in the salary_in_usd column.
# * We will not need the salary and salary_currency columns, we will only use the salaries in dollars.
# * When we look at the type of currency in the salary_currency column with the unique() function, there is no need to convert 20 currencies into a common currency.

# %%
x = df.salary_currency.unique()
x
# Out:
# array(['EUR', 'USD', 'INR', 'HKD', 'CHF', 'GBP', 'AUD', 'SGD', 'CAD',
#        'ILS', 'BRL', 'THB', 'PLN', 'HUF', 'CZK', 'DKK', 'JPY', 'MXN',
#        'TRY', 'CLP'], dtype=object)

# %%
len(x)
# Out:
# 20

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# * salary ve salary_currency sütunlarını veri setimizden silebiliriz.
# * we can delete salary and salary_currency columns from our dataset.

# %% [markdown]
# * salary sütunu sildik.
# * We deleted the salary column.

# %%
df = df.drop(["salary"], axis=1)
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# * salary_currency sütunu sildik.
# * We deleted the salary_currency column.

# %%
df = df.drop(["salary_currency"], axis=1)
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# * Maaşların karşılaştırmasını yaparken şirket konumununa göre yapacağız. Bunu için employee_residence sütununuda siliyoruz.
# * When comparing salaries, it is based on establishing a company. For this, we delete the staff_residence column.

# %%
df = df.drop(["employee_residence"], axis=1)
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#       salary_in_usd  remote_ratio company_location company_size
# ...

# %% [markdown]
# ### Veri Görselleştirme
# ### DATA VISUALIZATION

# %% [markdown]
# * Çalışma tipinin maaş üzerinde nasıl bir etkisi var ?
# * What effect does the type of work have on the salary?

# %%
x = df["employment_type"]
y = df["salary_in_usd"]

# %%
plt.scatter(x,y)
plt.xlabel("Employment Type")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# * Grafiği incelediğimizde çalışma tipinin maaş üzerinde ciddi bir etkisi olduğunu görüyoruz.
# * En çok kazananların full-time diğer çalışma tiplerinin arasında bir fark olmadığı grafikte belli oluyor bir kaç istisna dışında.
